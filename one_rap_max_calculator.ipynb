# %%
import matplotlib.pyplot as plt

def calculate_1_rep_max(weight, repetitions):
   percentage = 100 - (repetitions - 1) * 3
   return weight / (percentage / 100)


weight = float(input("Enter weight (kg): "))
repetitions = int(input("Enter number of repetitions: "))


one_rep_max = calculate_1_rep_max(kilo, tekrar)


plt.plot(repetitions, one_rep_max, 'ro', markersize=8)
plt.xlabel('Repetitions', fontsize=12)
plt.ylabel('1 REP MAX (kg)', fontsize=12)
plt.title('Relationship between 1 REP MAX and Repetitions', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)
plt.tight_layout()


print(f"1 REP MAX: {one_rep_max:.2f} kg")


plt.show()
# Out:
# Enter weight (kg): 60
# Enter number of repetitions: 5
# 1 REP MAX: 68.18 kg
